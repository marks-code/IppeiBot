# %%
import os
import time
from bs4 import BeautifulSoup
from playwright.sync_api import sync_playwright
from concurrent.futures import ThreadPoolExecutor
import pandas as pd

SEASONS = list(range(2024, 2026))

DATA_DIR = "data"
STANDINGS_DIR = os.path.join(DATA_DIR, "standings")
SCORES_DIR = os.path.join(DATA_DIR, "scores")

os.makedirs(STANDINGS_DIR, exist_ok=True)
os.makedirs(SCORES_DIR, exist_ok=True)

def get_html(url, selector, sleep=5, retries=3):
    html = None
    for i in range(1, retries + 1):
        time.sleep(sleep * i)
        try:
            def fetch():
                with sync_playwright() as p:
                    browser = p.firefox.launch()
                    page = browser.new_page()
                    page.goto(url)
                    print(page.title())
                    content = page.inner_html(selector)
                    browser.close()
                    return content

            with ThreadPoolExecutor(max_workers=1) as executor:
                future = executor.submit(fetch)
                html = future.result()

        except Exception as e:
            print(f"Error fetching {url}: {e}")
            continue
        else:
            break
    return html

def scrape_season(season):
    url = f"https://www.basketball-reference.com/leagues/NBA_{season}_games.html"
    html = get_html(url, "#content .filter")

    if not html:
        print(f"Failed to retrieve data for season {season}")
        return

    soup = BeautifulSoup(html, "html.parser")
    links = soup.find_all("a")
    standings_pages = [f"https://www.basketball-reference.com{l['href']}" for l in links if 'href' in l.attrs]

    for url in standings_pages:
        save_path = os.path.join(STANDINGS_DIR, url.split("/")[-1])

        if os.path.exists(save_path):
            print(f"File already exists: {save_path}, skipping...")
            continue

        html = get_html(url, "#all_schedule")

        if html:
            with open(save_path, "w+", encoding="utf-8") as f:
                f.write(html)
            print(f"Saved: {save_path}")
        else:
            print(f"Failed to retrieve: {url}")

for season in SEASONS:
    scrape_season(season)

standings_files = os.listdir(STANDINGS_DIR)

def scrape_game(standings_file):
    with open(standings_file, 'r', encoding="utf-8") as f:
        html = f.read()

    soup = BeautifulSoup(html, "html.parser")
    links = soup.find_all("a")
    hrefs = [l.get('href') for l in links]
    box_scores = [f"https://www.basketball-reference.com{l}" for l in hrefs if l and "boxscore" in l and '.html' in l]

    for url in box_scores:
        save_path = os.path.join(SCORES_DIR, url.split("/")[-1])
        if os.path.exists(save_path):
            continue

        html = get_html(url, "#content")
        if not html:
            continue
        with open(save_path, "w+", encoding="utf-8") as f:
            f.write(html)

for season in SEASONS:
    files = [s for s in standings_files if str(season) in s]
    for f in files:
        filepath = os.path.join(STANDINGS_DIR, f)
        scrape_game(filepath)

# Fetching game statistics
import os
import time
import pandas as pd
import requests
from bs4 import BeautifulSoup

SCORE_DIR = "data/scores"
os.makedirs(SCORE_DIR, exist_ok=True)

BASE_URL = "https://www.basketball-reference.com"
SEASON = "2025"
SCHEDULE_URL = f"{BASE_URL}/leagues/NBA_{SEASON}_games.html"
HEADERS = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36"}

# Get all monthly schedule URLs
response = requests.get(SCHEDULE_URL, headers=HEADERS)
soup = BeautifulSoup(response.text, "html.parser")
month_links = [a["href"] for a in soup.select("div.filter a")]

# Collect all game URLs
game_urls = []
for month_link in month_links:
    month_url = BASE_URL + month_link
    response = requests.get(month_url, headers=HEADERS)
    soup = BeautifulSoup(response.text, "html.parser")
    game_urls += [BASE_URL + a["href"] for a in soup.select("td[data-stat='box_score_text'] a")]
    time.sleep(2)  # Prevent getting blocked

print(f"Found {len(game_urls)} game box scores")

games = []
base_cols = None

for i, url in enumerate(game_urls):
    time.sleep(2)  # Prevent getting blocked
    response = requests.get(url, headers=HEADERS)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, "html.parser")
        
        try:
            line_score = pd.read_html(str(soup), attrs={'id': 'line_score'})[0]
            cols = list(line_score.columns)
            cols[0] = "team"
            cols[-1] = "total"
            line_score.columns = cols
            line_score = line_score[["team", "total"]]
        except Exception as e:
            print(f"Skipping {url} due to missing line score: {e}")
            continue
        
        teams = list(line_score["team"])
        summaries = []
        for team in teams:
            try:
                basic = pd.read_html(str(soup), attrs={'id': f'box-{team}-game-basic'}, index_col=0)[0]
                advanced = pd.read_html(str(soup), attrs={'id': f'box-{team}-game-advanced'}, index_col=0)[0]
                totals = pd.concat([basic.iloc[-1,:], advanced.iloc[-1,:]])
                totals.index = totals.index.str.lower()
                maxes = pd.concat([basic.iloc[:-1].max(), advanced.iloc[:-1].max()])
                maxes.index = maxes.index.str.lower() + "_max"
                summary = pd.concat([totals, maxes])
                if base_cols is None:
                    base_cols = list(summary.index.drop_duplicates(keep="first"))
                    base_cols = [b for b in base_cols if "bpm" not in b]
                summary = summary[base_cols]
                summaries.append(summary)
            except Exception as e:
                print(f"Skipping {url} due to missing stats for {team}: {e}")
                continue
        
        if summaries:
            summary = pd.concat(summaries, axis=1).T
            game = pd.concat([summary, line_score], axis=1)
            game["home"] = [0, 1]
            game_opp = game.iloc[::-1].reset_index()
            game_opp.columns += "_opp"
            full_game = pd.concat([game, game_opp], axis=1)
            full_game["season"] = SEASON
            full_game["date"] = pd.to_datetime(url.split("/")[-1][:8], format="%Y%m%d")
            full_game["won"] = full_game["total"] > full_game["total_opp"]
            games.append(full_game)
        
        if len(games) % 100 == 0:
            print(f"{len(games)} / {len(game_urls)} games processed")
    else:
        print(f"Failed to download {url}")

if not games:
    print("No valid games were processed!")
else:
    games_df = pd.concat(games, ignore_index=True)
    csv_path = os.path.join(SCORE_DIR, "games_data.csv")
    games_df.to_csv(csv_path, index=False)
    print(f"DataFrame successfully saved to {csv_path}!")
# Out:
# 2023-24 NBA Schedule | Basketball-Reference.com
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-october.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-november.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-december.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-january.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-february.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-march.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-april.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-may.html
# 2023-24 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2024_games-june.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-october.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-november.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-december.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-january.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-february.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-march.html
# 2024-25 NBA Schedule | Basketball-Reference.com
# Saved: data/standings/NBA_2025_games-april.html
# 2024 NBA Eastern Conference First Round Game 5: Heat vs Celtics, May 1, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference First Round Game 5: Mavericks vs Clippers, May 1, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference First Round Game 6: Bucks vs Pacers, May 2, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference First Round Game 6: Knicks vs 76ers, May 2, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference First Round Game 6: Cavaliers vs Magic, May 3, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference First Round Game 6: Clippers vs Mavericks, May 3, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 1: Timberwolves vs Nuggets, May 4, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference First Round Game 7: Magic vs Cavaliers, May 5, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 1: Pacers vs Knicks, May 6, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 2: Timberwolves vs Nuggets, May 6, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 1: Cavaliers vs Celtics, May 7, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 1: Mavericks vs Thunder, May 7, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 2: Pacers vs Knicks, May 8, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 2: Cavaliers vs Celtics, May 9, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 2: Mavericks vs Thunder, May 9, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 3: Knicks vs Pacers, May 10, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 3: Nuggets vs Timberwolves, May 10, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 3: Thunder vs Mavericks, May 11, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 3: Celtics vs Cavaliers, May 11, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 4: Knicks vs Pacers, May 12, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 4: Nuggets vs Timberwolves, May 12, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 4: Celtics vs Cavaliers, May 13, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 4: Thunder vs Mavericks, May 13, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 5: Pacers vs Knicks, May 14, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 5: Timberwolves vs Nuggets, May 14, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 5: Cavaliers vs Celtics, May 15, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 5: Mavericks vs Thunder, May 15, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 6: Nuggets vs Timberwolves, May 16, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 6: Knicks vs Pacers, May 17, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 6: Thunder vs Mavericks, May 18, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Semifinals Game 7: Pacers vs Knicks, May 19, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Semifinals Game 7: Timberwolves vs Nuggets, May 19, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Finals Game 1: Pacers vs Celtics, May 21, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Finals Game 1: Mavericks vs Timberwolves, May 22, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Finals Game 2: Pacers vs Celtics, May 23, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Finals Game 2: Mavericks vs Timberwolves, May 24, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Finals Game 3: Celtics vs Pacers, May 25, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Finals Game 3: Timberwolves vs Mavericks, May 26, 2024 | Basketball-Reference.com
# 2024 NBA Eastern Conference Finals Game 4: Celtics vs Pacers, May 27, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Finals Game 4: Timberwolves vs Mavericks, May 28, 2024 | Basketball-Reference.com
# 2024 NBA Western Conference Finals Game 5: Mavericks vs Timberwolves, May 30, 2024 | Basketball-Reference.com
# Error fetching https://www.basketball-reference.com/boxscores/202403010DET.html: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010DET.html", waiting until "load"
#
# Error fetching https://www.basketball-reference.com/boxscores/202403010DET.html: Page.goto: NS_ERROR_UNKNOWN_HOST
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010DET.html", waiting until "load"
#
# Error fetching https://www.basketball-reference.com/boxscores/202403010DET.html: Page.goto: NS_ERROR_UNKNOWN_HOST
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010DET.html", waiting until "load"
#
# Hornets vs 76ers, March 1, 2024 | Basketball-Reference.com
# Mavericks vs Celtics, March 1, 2024 | Basketball-Reference.com
# Error fetching https://www.basketball-reference.com/boxscores/202403010TOR.html: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010TOR.html", waiting until "load"
#
# Error fetching https://www.basketball-reference.com/boxscores/202403010TOR.html: Page.goto: NS_ERROR_UNKNOWN_HOST
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010TOR.html", waiting until "load"
#
# Error fetching https://www.basketball-reference.com/boxscores/202403010TOR.html: Page.goto: NS_ERROR_UNKNOWN_HOST
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010TOR.html", waiting until "load"
#
# Trail Blazers vs Grizzlies, March 1, 2024 | Basketball-Reference.com
# Error fetching https://www.basketball-reference.com/boxscores/202403010MIN.html: Page.goto: Timeout 30000ms exceeded.
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010MIN.html", waiting until "load"
#
# Error fetching https://www.basketball-reference.com/boxscores/202403010MIN.html: Page.goto: NS_ERROR_UNKNOWN_HOST
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403010MIN.html", waiting until "load"
#
# Error fetching https://www.basketball-reference.com/boxscores/202403010MIN.html: Page.goto: NS_ERROR_UNKNOWN_HOST
# Call log:
#   - navigating to "https://www.basketball-reference.com/boxscores/202403
# Raptors vs Nets, November 28, 2023 | Basketball-Reference.com
# Hawks vs Cavaliers, November 28, 2023 | Basketball-Reference.com
# Bucks vs Heat, November 28, 2023 | Basketball-Reference.com
# Hornets vs Knicks, November 28, 2023 | Basketball-Reference.com
# Thunder vs Timberwolves, November 28, 2023 | Basketball-Reference.com
# Rockets vs Mavericks, November 28, 2023 | Basketball-Reference.com
# Warriors vs Kings, November 28, 2023 | Basketball-Reference.com
# Lakers vs Pistons, November 29, 2023 | Basketball-Reference.com
# Wizards vs Magic, November 29, 2023 | Basketball-Reference.com
# Suns vs Raptors, November 29, 2023 | Basketball-Reference.com
# Jazz vs Grizzlies, November 29, 2023 | Basketball-Reference.com
# 76ers vs Pelicans, November 29, 2023 | Basketball-Reference.com
# Rockets vs Nuggets, November 29, 2023 | Basketball-Reference.com
# Clippers vs Kings, November 29, 2023 | Basketball-Reference.com
# Trail Blazers vs Cavaliers, November 30, 2023 | Basketball-Reference.com
# Hornets vs Nets, November 30, 2023 | Basketball-Reference.com
# Pacers vs Heat, November 30, 2023 | Basketball-Reference.com
# Pistons vs Knicks, November 30, 2023 | Basketball-Reference.com
# Bucks vs Bulls, November 30, 2023 | Basketball-Reference.com
# Jazz vs Timberwolves, November 30, 2023 | Basketball-Reference.com
# Lakers vs Thunder, November 30, 2023 | Basketball-Reference.com
# Hawks vs Spurs, November 30, 2023 | Basketball-Reference.com
# Clippers vs Warriors, November 30, 2023 | Basketball-Reference.com
# Wizards vs Magic, December 1, 2023 | Basketball-Reference.com
# 76ers vs Celtics, December 1, 2023 | Basketball-Reference.com
# Grizzlies vs Mavericks, December 1, 2023 | Basketball-Reference.com
# Knicks vs Raptors, December 1, 2023 | Basketball-Reference.com
# Spurs vs Pelicans, December 1, 2023 | Basketball-Reference.com
# Nuggets vs Suns, December 1, 2023 | Basketball-Reference.com
# Warriors vs Clippers, December 2, 2023 | Basketball-Reference.com
# Timberwolves vs Hornets, December 2, 2023 | Basketball-Reference.com
# Magic vs Nets, December 2, 2023 | Basketball-Reference.com
# Cavaliers vs Pistons, December 2, 2023 | Basketball-Reference.com
# Pelicans vs Bulls, December 2, 2023 | Basketball-Reference.com
# Pacers vs Heat, December 2, 2023 | Basketball-Reference.com
# Hawks vs Bucks, December 2, 2023 | Basketball-Reference.com
# Thunder vs Mavericks, December 2, 2023 | Basketball-Reference.com
# Grizzlies vs Suns, December 2, 2023 | Basketball-Reference.com
# Trail Blazers vs Jazz, December 2, 2023 | Basketball-Reference.com
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 100
#      98     for f in files:
#      99         filepath = os.path.join(STANDINGS_DIR, f)
# --> 100         scrape_game(filepath)
#     102 # Fetching game statistics
#     103 import os
#
# Cell In[1], line 90, in scrape_game(standings_file)
#      87 if os.path.exists(save_path):
#      88     continue
# ---> 90 html = get_html(url, "#content")
#      91 if not html:
#      92     continue
#
# Cell In[1], line 34, in get_html(url, selector, sleep, retries)
#      32     with ThreadPoolExecutor(max_workers=1) as executor:
#      33         future = executor.submit(fetch)
# ---> 34         html = future.result()
#      36 except Exception as e:
#      37     print(f"Error fetching {url}: {e}")
#
# File ~/anaconda3/lib/python3.11/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
#     449     return self.__get_result()
# --> 451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#     454     raise CancelledError()
#
# File ~/anaconda3/lib/python3.11/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:
